# %%
# !pip3 install colabTurtle

#파이썬 터틀 특별히 코랩에서 활용가능한 터틀이라는 도구를 설치하는 코드

# %% [markdown]
# 색깔 참조
# https://encycolorpedia.kr/html

# %%
#파이썬 터틀 배경 설정하기

import ColabTurtle.Turtle as t #도구 이름이 너무 기니 t로 줄여주기!
t.initializeTurtle() #화면 초기화
t.bgcolor('skyblue') #bgcolor 무슨 색깔? : 
t.color('blue') #color 무슨 색깔? :
t.speed(10) #그림 그리는 속도

#거북이 위치와 화면 크기 숫자로 표시 
print(t.position())
print(t.window_size)

# %%
#파이썬 터틀로 삼각형 그리기!

import ColabTurtle.Turtle as t #도구 이름이 너무 기니 t로 줄여주기!
t.initializeTurtle() 
t.bgcolor('skyblue') 
t.color('blue') 
t.speed(1) #그림 그리는 속도

for i in range(3): #몇번 반복? :
  t.fd(120) #fd는 ? forward의 준말 : 
  t.rt(120) #rt는 ? right의 준말 : 
  #t.bk(120) #bk는 ? backward의 준말 : 


#거북이 위치와 화면 크기 숫자로 표시 
print(t.position())
print(t.window_size)

# %%
#파이썬 터틀로 원 그리기 

import ColabTurtle.Turtle as t #도구 이름이 너무 기니 t로 줄여주기!
t.initializeTurtle() 
t.bgcolor('skyblue') 
t.color('blue') 
t.speed(10) #그림 그리는 속도

for i in range():
  t.fd(1) #앞으로 1만큼 전진
  t.rt(1) #오른쪽으로 1도만큼 돌기

t.hideturtle() #거북이 모양을 숨겨주기

#거북이 위치와 화면 크기 숫자로 표시 
print(t.position())
print(t.window_size)

# %%
#파이썬 터틀로 사각형 그리기! 

import ColabTurtle.Turtle as t #도구 이름이 너무 기니 t로 줄여주기!
t.initializeTurtle() 
t.bgcolor('skyblue') 
t.color('blue')
t.speed(1) #그림 그리는 속도

for i in range(): 
  t.fd() #fd는 ? forward의 준말 : 
  t.rt() #rt는? right의 준말 : 
  #t.bk() #bk는 ? backward의 준말 : 

#거북이 위치와 화면 크기 숫자로 표시 
print(t.position())
print(t.window_size)

# %%
#내가 원하는 길이와 속도 입력하면 그 크기만큼 사각형 그려주는 파이썬 터틀!

# %%
#파이썬 터틀로 별 그리기

import ColabTurtle.Turtle as t #도구 이름이 너무 기니 t로 줄여주기!
t.initializeTurtle()
t.bgcolor('skyblue') 
t.color('blue') 
t.speed(1) 

t.pu() #펜 들기 
t.goto(300,400) #x축 300, y축 400으로 거북이 이동
t.pd() #팬네리기 

#펜을 들어서 원하는 위치에 내려 점을 찍어준다(시작점을 찍어준다)

for i in range(1,6): 
  t.fd(100) 
  t.rt(144)


#거북이 위치와 화면 크기 숫자로 표시 
print(t.position())
print(t.window_size)

# %%
# 위에서 한 것을 종합해서 삼각형, 사각형, 별 그리기 (원도 추가!)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="skyblue"/>
#         <line x1="400" y1="250" x2="400.0" y2="130.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="130.0" x2="503.923" y2="190.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="503.923" y1="190.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300" y1="400" x2="300.0" y2="280.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="280.0" x2="420.0" y2="280.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="420.0" y1="280.0" x2="420.0" y2="400.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="420.0" y1="400.0" x2="300.0" y2="400.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="600" y1="300" x2="600.0" y2="200.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="600.0" y1="200.0" x2="658.779" y2="280.902" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="658.779" y1="280.902" x2="563.673" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="563.673" y1="250.0" x2="658.779" y2="219.098" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="658.779" y1="219.098" x2="600.0" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,600.0,300.0) translate(582.0, 282.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:orange;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %%
# 코랩에서 안되는 것들은 앞에 # 붙여놓음

# 초기 세팅 
import ColabTurtle.Turtle as t# 라이브러리 불러오기
t.initializeTurtle() #거북이 만들기 
t.shape("turtle")      # 커서모양 arrow, circle, square, triangle, classic

# 설정함수 - 메서드 (배경색깔, 펜 색깔, 펜 모양)

t.bgcolor("black")  # red, purple, blue, green, yello, orange
t.bgcolor(r,g,b) #r,g,b 색깔을 입력하면 원하는 색깔 표시할 수 있음
t.pencolor("red")        # 선색상
t.pencolor(r,g,b) #r,g,b, 색깔을 입력하면 원하는 펜 색깔 표시할 수 있음
t.speed(0)               # 이동속도
t.width(3)               # 선굵기


#이동함수 - 메서드 
t.forward(100)  # 전진, 길이 = t.fd(100)
t.backward(100) # 후진, 길이 = t.bk(100)
t.right(90)     # 우회전, 각도 = t.rt(90)
t.left(90)      # 좌회전, 각도 = t.lt(90)
#t.circle(100)   # 원, 반지름 
t.penup()       # 펜 올리기, 그리지 않기 = t.up()
t.pendown()     # 펜 내리기, 그리기 = t.down()
t.goto(0,0)     # 좌표이동
t.heading()     # 현재의 방향을 반환
t.position()    # 현재의 위치 반환
t.dot()         # 현재의 위치에 점찍기

#화면에 글짜 출력

t.write("안녕하세요")

#색상 채우기  (코랩에서는 안됨 ㅠㅠ)

#t.fillcolor("yellow")  # 채우기 색상. red, blue, green
#t.begin_fill()       # 채우기 시작
#t.circle(100)
#t.end_fill()         # 채우기 종료

# %%
#추가 예제 1
import ColabTurtle.Turtle as t #도구 이름이 너무 기니 t로 줄여주기!
t.initializeTurtle()
t.bgcolor(0,191,255) #bgcolor 무슨 색깔? : 
t.color('black') #color 무슨 색깔? :
t.speed(5) #그림 그리는 속도

#사각형을 그리는 함수 (한 변이 side인 정사각형을 그려라)
def rect(t, side):
    for i in range(4):
        t.forward(side)
        t.left(90)  


#side만큼의  10번 그리기 
side = 200
for n in range(10):
    rect(t, side)
    t.lt(10) #왼쪽으로 10도 돌기
    side -= 10

# %%
#추가 예제 2
import ColabTurtle.Turtle as tree

tree.initializeTurtle()
tree.bgcolor(255,255,255) 
tree.speed(10)
MINIMUM_BRANCH_LENGTH = 5

def build_tree(t, branch_length, shorten_by, angle):
  if branch_length > MINIMUM_BRANCH_LENGTH:
    t.forward(branch_length)
    new_length = branch_length - shorten_by

    t.left(angle)
    build_tree(t, new_length, shorten_by, angle)

    t.right(angle * 2)
    build_tree(t, new_length, shorten_by, angle)

    t.left(angle)
    t.backward(branch_length)

tree.hideturtle()
tree.setheading(90)
tree.color('green')

build_tree(tree, 50, 5, 30)

# %%
#나만의 파이썬 터틀 그리기!!!
